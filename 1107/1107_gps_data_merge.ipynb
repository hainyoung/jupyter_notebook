# %%
import pandas as pd
import numpy as np

# %%
gps_0 = pd.read_csv('./device0_gps_2020-11-07_edit.csv', encoding = 'utf-8')
gps_0
# Out:
#                     rtime provider device_name   latitude  longtitude  \
# 0     2020-11-07 13:14:16      gps     device0  37.391009  126.973803
# 1     2020-11-07 13:14:17      gps     device0  37.390537  126.973369
# 2     2020-11-07 13:14:18      gps     device0  37.390071  126.973497
# 3     2020-11-07 13:14:25      gps     device0  37.388576  126.972667
# 4     2020-11-07 13:14:26      gps     device0  37.388506  126.972497
# ...                   ...      ...         ...        ...         ...
# 7706  2020-11-07 16:22:10      gps     device0  37.359742  126.966695
# 7707  2020-11-07 16:22:11      gps     device0  37.359746  126.966708
# 7708  2020-11-07 16:22:12      gps     device0  37.359749  126.966718
# 7709  2020-11-07 16:22:14      gps     device0  37.359763  126.966749
# 7710  2020-11-07 16:22:15      gps     device0  37.359763  126.966752
#
#         altitude      speed  accuracy       time_utc
# 0     -35.134254  52.069386       192  1604722456094
# ...

# %%
gps_1 = pd.read_csv('./device1_gps_2020-11-07_edit.csv', encoding = 'utf-8')
gps_1
# Out:
#                     rtime provider device_name   latitude  longtitude  \
# 0     2020-11-07 13:14:39      gps     device1  37.389346  126.972683
# 1     2020-11-07 13:14:40      gps     device1  37.389157  126.972628
# 2     2020-11-07 13:14:41      gps     device1  37.388702  126.972642
# 3     2020-11-07 13:14:42      gps     device1  37.389036  126.972675
# 4     2020-11-07 13:14:43      gps     device1  37.389068  126.972657
# ...                   ...      ...         ...        ...         ...
# 4918  2020-11-07 16:17:36      gps     device1  37.336048  126.980682
# 4919  2020-11-07 16:17:37      gps     device1  37.336266  126.980623
# 4920  2020-11-07 16:17:38      gps     device1  37.336452  126.980602
# 4921  2020-11-07 16:17:39      gps     device1  37.336637  126.980555
# 4922  2020-11-07 16:17:40      gps     device1  37.336842  126.980459
#
#        altitude      speed  accuracy       time_utc
# 0    -96.465741   2.189828       128  1604722479930
# ...

# %%
gps_2 = pd.read_csv('./device2_gps_2020-11-07_edit.csv', encoding = 'utf-8')
gps_2
# Out:
#                     rtime provider device_name   latitude  longtitude  \
# 0     2020-11-07 13:15:02      gps     device2  37.389417  126.972288
# 1     2020-11-07 13:15:03      gps     device2  37.389562  126.972305
# 2     2020-11-07 13:15:04      gps     device2  37.389723  126.972549
# 3     2020-11-07 13:15:05      gps     device2  37.389349  126.972734
# 4     2020-11-07 13:15:06      gps     device2  37.389116  126.972778
# ...                   ...      ...         ...        ...         ...
# 5033  2020-11-07 16:15:51      gps     device2  37.318557  126.992018
# 5034  2020-11-07 16:15:52      gps     device2  37.318640  126.991819
# 5035  2020-11-07 16:15:53      gps     device2  37.318716  126.991639
# 5036  2020-11-07 16:15:54      gps     device2  37.318811  126.991465
# 5037  2020-11-07 16:22:08      gps     device2  37.359607  126.967010
#
#         altitude      speed  accuracy       time_utc
# 0     -23.589586   0.650529       128  1604722502138
# ...

# %%
gps_data_concat = pd.concat([gps_0, gps_1, gps_2])
gps_data_concat = gps_data.reset_index()

# %%
gps_data_concat = gps_data_concat[['rtime', 'provider', 'device_name', 'latitude', 'longtitude', 'altitude', 'speed', 'accuracy', 'time_utc']]
gps_data_concat
# Out:
#                      rtime provider device_name   latitude  longtitude  \
# 0      2020-11-07 13:14:16      gps     device0  37.391009  126.973803
# 1      2020-11-07 13:14:17      gps     device0  37.390537  126.973369
# 2      2020-11-07 13:14:18      gps     device0  37.390071  126.973497
# 3      2020-11-07 13:14:25      gps     device0  37.388576  126.972667
# 4      2020-11-07 13:14:26      gps     device0  37.388506  126.972497
# ...                    ...      ...         ...        ...         ...
# 17667  2020-11-07 16:15:51      gps     device2  37.318557  126.992018
# 17668  2020-11-07 16:15:52      gps     device2  37.318640  126.991819
# 17669  2020-11-07 16:15:53      gps     device2  37.318716  126.991639
# 17670  2020-11-07 16:15:54      gps     device2  37.318811  126.991465
# 17671  2020-11-07 16:22:08      gps     device2  37.359607  126.967010
#
#          altitude      speed  accuracy       time_utc
# 0      -35.134254  52.069386       192  1604722456094
# ...

# %%
gps_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17672 entries, 0 to 17671
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rtime        17672 non-null  object
#  1   provider     17672 non-null  object
#  2   device_name  17672 non-null  object
#  3   latitude     17672 non-null  float64
#  4   longtitude   17672 non-null  float64
#  5   altitude     17672 non-null  float64
#  6   speed        17672 non-null  float64
#  7   accuracy     17672 non-null  int64
#  8   time_utc     17672 non-null  int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
gps_data_concat.to_csv('./1107_gps_concat.csv', index=False, encoding = 'utf-8')

# %%
gps_data_concat_time = pd.read_csv('./1107_gps_concat_time.csv', encoding = 'utf-8')
gps_data_concat_time
# Out:
#                      rtime provider device_name   latitude  longtitude  \
# 0      2020-11-07 13:14:16      gps     device0  37.391009  126.973803
# 1      2020-11-07 13:14:17      gps     device0  37.390537  126.973369
# 2      2020-11-07 13:14:18      gps     device0  37.390071  126.973497
# 3      2020-11-07 13:14:25      gps     device0  37.388576  126.972667
# 4      2020-11-07 13:14:26      gps     device0  37.388506  126.972497
# ...                    ...      ...         ...        ...         ...
# 17667  2020-11-07 16:22:10      gps     device0  37.359742  126.966695
# 17668  2020-11-07 16:22:11      gps     device0  37.359746  126.966708
# 17669  2020-11-07 16:22:12      gps     device0  37.359749  126.966718
# 17670  2020-11-07 16:22:14      gps     device0  37.359763  126.966749
# 17671  2020-11-07 16:22:15      gps     device0  37.359763  126.966752
#
#          altitude      speed  accuracy      time_utc
# 0      -35.134254  52.069386       192  1.604720e+12
# ...

# %%
gps_data_concat_time.duplicated(['rtime']).sum()
# Out:
# 9369

# %%
gps_data_concat_time.duplicated(['rtime'], keep='first')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17667    False
# 17668    False
# 17669    False
# 17670    False
# 17671    False
# Length: 17672, dtype: bool

# %%
gps_clean_data = gps_data_concat_time.drop_duplicates('rtime', keep='first')
gps_clean_data
# Out:
#                      rtime provider device_name   latitude  longtitude  \
# 0      2020-11-07 13:14:16      gps     device0  37.391009  126.973803
# 1      2020-11-07 13:14:17      gps     device0  37.390537  126.973369
# 2      2020-11-07 13:14:18      gps     device0  37.390071  126.973497
# 3      2020-11-07 13:14:25      gps     device0  37.388576  126.972667
# 4      2020-11-07 13:14:26      gps     device0  37.388506  126.972497
# ...                    ...      ...         ...        ...         ...
# 17667  2020-11-07 16:22:10      gps     device0  37.359742  126.966695
# 17668  2020-11-07 16:22:11      gps     device0  37.359746  126.966708
# 17669  2020-11-07 16:22:12      gps     device0  37.359749  126.966718
# 17670  2020-11-07 16:22:14      gps     device0  37.359763  126.966749
# 17671  2020-11-07 16:22:15      gps     device0  37.359763  126.966752
#
#          altitude      speed  accuracy      time_utc
# 0      -35.134254  52.069386       192  1.604720e+12
# ...

# %%
gps_clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8303 entries, 0 to 17671
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rtime        8303 non-null   object
#  1   provider     8303 non-null   object
#  2   device_name  8303 non-null   object
#  3   latitude     8303 non-null   float64
#  4   longtitude   8303 non-null   float64
#  5   altitude     8303 non-null   float64
#  6   speed        8303 non-null   float64
#  7   accuracy     8303 non-null   int64
#  8   time_utc     8303 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 648.7+ KB

# %%
gps_clean_data.to_csv('./1107_merged_gps_data.csv', index = False, encoding = 'utf-8')
